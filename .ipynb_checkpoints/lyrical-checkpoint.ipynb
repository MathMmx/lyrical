# %%
import pandas as pd

df = pd.read_csv("letras_sertanejo.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("letras_sertanejo.csv")
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File c:\Users\momoc\anaconda3\Lib\site-packages\pandas\io\common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'letras_sertanejo.csv'

# %%
df
# Out:
#                                 Artistas                    Nome da Musica  \
# 0                          Simone Mendes                      Dois Tristes
# 1           Simone Mendes, Manu Bahtidao                  Daqui pra Frente
# 2              Gusttavo Lima, Traia Veia                        Equivocada
# 3         Gusttavo Lima. Bruno e Marrone                    Relacao Errada
# 4      Manu Bahtidao, Guilherme e Benuto                      Torre Eiffel
# 5                    Ze Neto e Cristiano                         Deu moral
# 6                    Diego e Victor Hugo                   Bem mais que eu
# 7  Rionegro e Solimoes, Maiara e Maraisa  Isso e coisa de quem quer voltar
# 8         Thiago e Samuel, Simone Mendes                    Amor diferente
# 9           Jorge e Mateus, Lauana Prado                     Havera sinais
#
#                                                Letra
# 0  Oh, oh\r\nOntem saímos de novo\r\nE você embur...
# 1  Joga, joga a mão em cima\r\nJoga a mão e grita...
# 2  Eu\r\nDentro do meu carro\r\nIndo pro trabalho...
# 3  E eu já te pedi desculpa sem errar\r\nMe anule...
# 4  Eu rezo pra você achar\r\nO amor da sua vida\r...
# 5  Sempre tem um\r\nQue conhece outro\r\nQue conh...
# 6  Sei que você não 'tá entendendo nada\r\nTanta ...
# 7  Um "oi saudade", às três da tarde\r\nNão é nor...
# 8  Um beijo foda, já beijei\r\nUma cama quente, j...
# 9  Tá quase viu?\r\nOntem a noite eu beijei algué...

# %%
import re
from collections import Counter

# Funcao para processar as letras
def preprocess_lyrics(lyrics):
    # Normalize line breaks and whitespace
    lyrics = re.sub(r'\s+', ' ', lyrics).strip()
    # Convert to lowercase
    lyrics = lyrics.lower()
    # Remove punctuation
    lyrics = re.sub(r'[^\w\s]', '', lyrics)
    return lyrics

# Aplicar a funcao para as letras
df['Letras processadas'] = df['Letra'].apply(preprocess_lyrics)

# Mostrando as letras processadas para vizualizacao
df[['Artistas', 'Nome da Musica', 'Letras processadas']].head()
# Out:
#                             Artistas    Nome da Musica  \
# 0                      Simone Mendes      Dois Tristes
# 1       Simone Mendes, Manu Bahtidao  Daqui pra Frente
# 2          Gusttavo Lima, Traia Veia        Equivocada
# 3     Gusttavo Lima. Bruno e Marrone    Relacao Errada
# 4  Manu Bahtidao, Guilherme e Benuto      Torre Eiffel
#
#                                   Letras processadas
# 0  oh oh ontem saímos de novo e você emburrada co...
# 1  joga joga a mão em cima joga a mão e grita hey...
# 2  eu dentro do meu carro indo pro trabalho dando...
# 3  e eu já te pedi desculpa sem errar me anulei à...
# 4  eu rezo pra você achar o amor da sua vida algu...

# %%
# Combine all processed lyrics into a single text
all_lyrics = ' '.join(df['Letras processadas'])

# Count the occurrences of each word
word_counts = Counter(all_lyrics.split())

# Display the most common words
common_words = word_counts.most_common(200)
common_words
# Out:
# [('eu', 93),
#  ('que', 89),
#  ('e', 82),
#  ('a', 61),
#  ('de', 60),
#  ('não', 50),
#  ('te', 45),
#  ('gente', 44),
#  ('você', 42),
#  ('é', 42),
#  ('o', 37),
#  ('só', 35),
#  ('um', 29),
#  ('se', 29),
#  ('do', 28),
#  ('quem', 28),
#  ('pra', 27),
#  ('isso', 26),
#  ('com', 25),
#  ('mas', 25),
#  ('amor', 24),
#  ('na', 23),
#  ('quer', 22),
#  ('cê', 22),
#  ('tá', 20),
#  ('mais', 20),
#  ('briga', 20),
#  ('mesmo', 20),
#  ('voltar', 20),
#  ('no', 19),
#  ('coisa', 19),
#  ('acaba', 17),
#  ('por', 16),
#  ('todo', 15),
#  ('mundo', 14),
#  ('tudo', 14),
#  ('hey', 13),
#  ('vem', 13),
#  ('saudade', 13),
#  ('me', 12),
#  ('vai', 12),
#  ('tipo', 11),
#  ('assunto', 11),
#  ('da', 11),
#  ('sei', 11),
#  ('minha', 11),
#  ('alguém', 10),
#  ('ela', 10),
#  ('diferente', 10),
#  ('morre', 10),
#  ('oh', 9),
#  ('quando', 9),
#  ('dois', 9),
#  ('fica', 9),
#  ('já', 9),
#  ('boca', 9),
#  ('nada', 9),
#  ('nem', 9),
#  ('sua', 9),
#  ('ou', 9),
#  ('aqui', 9),
#  ('faz', 9),
#  ('meu', 8),
#  ('conheço', 8),
#  ('bebe', 8),
#  ('ver', 8),
#  ('ninguém', 8),
#  ('bem', 8),
#  ('chegou', 8),
#  ('até', 8),
#  ('choro', 8),
#  ('caiu', 8),
#  ('uma', 8),
#  ('paixão', 8),
#  ('saber', 8),
#  ('porque', 8),
#  ('sabe', 8),
#  ('cidade', 8),
#  ('tem', 7),
#  ('feliz', 7),
#  ('ele', 7),
#  ('aí', 7),
#  ('nós', 6),
#  ('errado', 6),
#  ('junto', 6),
#  ('mim', 6),
#  ('deu', 6),
#  ('joga', 6),
#  ('simone', 6),
#  ('mendes', 6),
#  ('comigo', 6),
#  ('onde', 6),
#  ('sempre', 6),
#  ('áudio', 6),
#  ('mandou', 6),
#  ('ao', 6),
#  ('eh', 6),
#  ('casa', 6),
#  ('deixa', 6),
#  ('dar', 6),
#  ('ser', 6),
#  ('melhor', 6),
#  ('moral', 6),
#  ('pouco', 6),
#  ('seu', 6),
#  ('beber', 6),
#  ('largou', 6),
#  ('ligar', 6),
#  ('lançar', 6),
#  ('meio', 6),
#  ('sonzeira', 6),
#  ('viu', 6),
#  ('esqueci', 6),
#  ('tinha', 5),
#  ('casal', 5),
#  ('lado', 5),
#  ('mão', 5),
#  ('lá', 5),
#  ('os', 5),
#  ('sabendo', 5),
#  ('ia', 5),
#  ('bar', 5),
#  ('orgulho', 5),
#  ('quase', 5),
#  ('haverá', 5),
#  ('sinais', 5),
#  ('ligando', 5),
#  ('to', 4),
#  ('sensação', 4),
#  ('escolhi', 4),
#  ('quanto', 4),
#  ('saio', 4),
#  ('claro', 4),
#  ('vejo', 4),
#  ('beija', 4),
#  ('língua', 4),
#  ('em', 4),
#  ('nosso', 4),
#  ('era', 4),
#  ('demais', 4),
#  ('olha', 4),
#  ('conquistou', 4),
#  ('daqui', 4),
#  ('tu', 4),
#  ('calando', 4),
#  ('amo', 4),
#  ('fim', 4),
#  ('manu', 4),
#  ('carro', 4),
#  ('madrugada', 4),
#  ('sinal', 4),
#  ('abria', 4),
#  ('fechava', 4),
#  ('engasguei', 4),
#  ('marcha', 4),
#  ('som', 4),
#  ('buzinada', 4),
#  ('ficha', 4),
#  ('traiu', 4),
#  ('distraiu', 4),
#  ('equivocada', 4),
#  ('dormiu', 4),
#  ('tão', 4),
#  ('também', 4),
#  ('leve', 4),
#  ('aviso', 4),
#  ('beijou', 4),
#  ('vacilou', 4),
#  ('quebrada', 4),
#  ('importante', 4),
#  ('vez', 4),
#  ('conto', 4),
#  ('conta', 4),
#  ('meus', 4),
#  ('pode', 4),
#  ('noite', 4),
#  ('foto', 4),
#  ('virar', 4),
#  ('ontem', 3),
#  ('cara', 3),
#  ('queria', 3),
#  ('esse', 3),
#  ('menos', 3),
#  ('pro', 3),
#  ('chega', 3),
#  ('bahtidão', 3),
#  ('obrigado', 3),
#  ('brigado', 3),
#  ('sem', 3),
#  ('às', 3),
#  ('mudar', 3),
#  ('tempo', 3),
#  ('relação', 3),
#  ('errada', 3),
#  ('batem', 3),
#  ('combinam', 3),
#  ('santo', 3),
#  ('casamenteiro', 3),
#  ('faça', 3),
#  ('acabou', 3)]

# %%
# Function to calculate lexical diversity
def lexical_diversity(text):
    words = text.split()
    return len(set(words)) / len(words)

# Calculate vocabulary size and lexical diversity for each song
df['Volume de Vocabulario'] = df['Letras processadas'].apply(lambda x: len(set(x.split())))
df['Diversidade Lexical'] = df['Letras processadas'].apply(lexical_diversity)

# Display the results
df[['Artistas', 'Nome da Musica', 'Volume de Vocabulario', 'Diversidade Lexical']].head()
# Out:
#                             Artistas    Nome da Musica  Volume de Vocabulario  \
# 0                      Simone Mendes      Dois Tristes                     77
# 1       Simone Mendes, Manu Bahtidao  Daqui pra Frente                     77
# 2          Gusttavo Lima, Traia Veia        Equivocada                     61
# 3     Gusttavo Lima. Bruno e Marrone    Relacao Errada                     70
# 4  Manu Bahtidao, Guilherme e Benuto      Torre Eiffel                    115
#
#    Diversidade Lexical
# 0             0.285185
# 1             0.292776
# 2             0.281106
# 3             0.309735
# 4             0.402098

# %%
def words_before_slash_r(text):
    linhas = text.strip().split('\r\n')
    ultimas_palavras = [linha.split()[-1] for linha in linhas if linha.split()]
    return ultimas_palavras

df['rhymes'] = df['Letra'].apply(words_before_slash_r)
df['rhymes']
# Out:
# 0    [oh, novo, emburrada, fechada, lado, boa, Deus...
# 1    [cima, grita, hey, Ceará, ó, falou, amor, dema...
# 2    [Eu, carro, trabalho, áudio, madrugada, desboc...
# 3    [errar, perder, agradar, fazer, parte, fazer, ...
# 4    [achar, vida, queria, feliz, quis, certo, sorr...
# 5    [um, outro, alguém, eu, tinha, bebeu, aqui, mi...
# 6    [nada, casa, razão, coração, pouco, importante...
# 7    [tarde, esquecer, madruga, beber, causa, cara"...
# 8    [beijei, deitei, jeito, peito, tirei, ver, voc...
# 9    [viu?, alguém, caiu, caiu, viu?, arrepiei, ass...
# Name: rhymes, dtype: object

# %%
df['rhymes'],['Dois Tristes']
# Out:
# (0    [oh, novo, emburrada, fechada, lado, boa, Deus...
#  1    [cima, grita, hey, Ceará, ó, falou, amor, dema...
#  2    [Eu, carro, trabalho, áudio, madrugada, desboc...
#  3    [errar, perder, agradar, fazer, parte, fazer, ...
#  4    [achar, vida, queria, feliz, quis, certo, sorr...
#  5    [um, outro, alguém, eu, tinha, bebeu, aqui, mi...
#  6    [nada, casa, razão, coração, pouco, importante...
#  7    [tarde, esquecer, madruga, beber, causa, cara"...
#  8    [beijei, deitei, jeito, peito, tirei, ver, voc...
#  9    [viu?, alguém, caiu, caiu, viu?, arrepiei, ass...
#  Name: rhymes, dtype: object,
#  ['Dois Tristes'])

# %%
df['rhymes'].head
# Out:
# <bound method NDFrame.head of 0    [oh, novo, emburrada, fechada, lado, boa, Deus...
# 1    [cima, grita, hey, Ceará, ó, falou, amor, dema...
# 2    [Eu, carro, trabalho, áudio, madrugada, desboc...
# 3    [errar, perder, agradar, fazer, parte, fazer, ...
# 4    [achar, vida, queria, feliz, quis, certo, sorr...
# 5    [um, outro, alguém, eu, tinha, bebeu, aqui, mi...
# 6    [nada, casa, razão, coração, pouco, importante...
# 7    [tarde, esquecer, madruga, beber, causa, cara"...
# 8    [beijei, deitei, jeito, peito, tirei, ver, voc...
# 9    [viu?, alguém, caiu, caiu, viu?, arrepiei, ass...
# Name: rhymes, dtype: object>

# %%
df
